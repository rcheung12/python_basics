# %% [markdown]
# # **This is an Extra Bold H1 Header**
# ## **This is an Extra Bold H2 Header**

# %% [markdown]
# Data Types
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Operators
#
# ![arithmetic_operators.png](attachment:arithmetic_operators.png)
# ![comparison_operators.png](attachment:comparison_operators.png)
